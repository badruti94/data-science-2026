# %% [markdown]
# Nama    : Badru
# NIM     : 200302310
# Kelas   : IF405

# %%
import pandas as pd, numpy as np
from scipy.stats.mstats import winsorize
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# step 0
df = pd.read_csv('/content/drive/MyDrive/data-science-2026/housing_dirty.csv')
print('Shape awal:', df.shape)
print(df.isnull().sum())
# Out:
# Shape awal: (130, 7)
# id               0
# luas_m2         18
# harga_juta      17
# kota             0
# kamar           10
# tahun_bangun     0
# kondisi          0
# dtype: int64

# %%
# step 1
df.drop_duplicates(inplace=True)
print('Setelah hapus duplikat:', df.shape)
# Out:
# Setelah hapus duplikat: (130, 7)

# %%
# step 2
df['kota'] = df['kota'].str.strip().str.title()
df['kondisi'] = df['kondisi'].str.strip().str.lower()

# %%
# step 3
df['luas_m2'] = df['luas_m2'].fillna(df['luas_m2'].median())
df['harga_juta'] = df['harga_juta'].fillna(df['harga_juta'].median())
df['kamar'] = df['kamar'].fillna(df['kamar'].mode()[0])

# %%
# step 4
for col in ['harga_juta', 'luas_m2', 'tahun_bangun']:
  Q1, Q3 = df[col].quantile([0.25, 0.75])
  IQR = Q3 - Q1
  df[col] = df[col].clip(Q1-1.5*IQR, Q3+1.5*IQR)

# %%
# step 5
assert df.isnull().sum().sum() == 0, 'Masih ada missing!'
assert df.duplicated().sum() == 0, 'masih ada duplikat!'
print('Shape akhir:', df.shape)
df.to_csv('/content/drive/MyDrive/data-science-2026/housing_clean.csv', index=False)
print('Dataset bersih tersimpan!')
# Out:
# Shape akhir: (130, 7)
# Dataset bersih tersimpan!

# %% [markdown]
# **Kesimpulan :**
#
# Pada pertemuan ini, saya telah mempelajari cara penanganan data kotor. Data berhasil dirapikan sehingga data menjadi bersih.
