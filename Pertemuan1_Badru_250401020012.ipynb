# %% [markdown]
# Nama    : Badru
# NIM     : 200302310
# Kelas   : IF405

# %% [markdown]
# <a href="https://colab.research.google.com/github/badruti94/Python3.x_Dasar_Programming/blob/master/latihan1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Latihan 1

# %%
#Output sederhana
print("Hello unsia")
# Out:
# Hello unsia

# %%
#variable dan tipe data
nama = "Badru"
angkatan = 2025

print(nama)
print(angkatan)
print(f"Halo nama saya {nama} dari angkatan {angkatan}")
# Out:
# Badru
# 2025
# Halo nama saya Badru dari angkatan 2025

# %%
#List
tools = ["Python", "Google colab", "Jupiter notebook", "Github"]

#Perulangan
for i in tools:
  print(i)
# Out:
# Python
# Google colab
# Jupiter notebook
# Github

# %%
#fungsi
def perkenalan(nama, prodi, angkatan):
  return print(f"Halo nama saya {nama} dari prodi {prodi} angkatan {angkatan}")

perkenalan("Badru", "Informatika", 2025)
# Out:
# Halo nama saya Badru dari prodi Informatika angkatan 2025

# %% [markdown]
# Kesimpulan
#
# Yang telah saya pelajari adalah dasar - dasar bahasa pemrograman python
